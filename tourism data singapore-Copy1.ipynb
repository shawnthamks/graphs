# %%
import pandas as pd
import numpy as np
import csv

read_file = pd.read_excel (r"/Users/user/Downloads/tourism_data2.xlsx")
read_file.to_csv (r"/Users/user/Downloads/tourism data.csv", index = None, header=True)
df_tourism = pd.read_csv (r"/Users/user/Downloads/tourism data.csv")
df_tourism.head()
# Out:
#         countries  Jan_1978  Feb_1978  Mar_1978  Apr_1978  May_1978  Jun_1978  \
# 0  Southeast_Asia     64500     57650     63299     73782     68036     67746
# 1           China        56         7        55        11         3         1
# 2   Hong_Kong_SAR      3148      5805      4510      3254      3212      3589
# 3          Taiwan      1956      1659      2460      2336      2143      2112
# 4           Japan     18652     20394     20136     13508     14472     12992
#
#    Jul_1978  Aug_1978  Sep_1978  ...  Jul_2019  Aug_2019  Sep_2019  Oct_2019  \
# 0     73672     82899     75304  ...    617766    520891    511619    555919
# 1        11         6         4  ...    389499    397066    248546    258602
# 2      5376      7059      3603  ...     50816     52767     35349     36072
# 3      2413      3421      2269  ...     55339     45774     33138     34588
# 4     15363     24656     13397  ...     71410    108104     80823     80103
#
# ...

# %%
import matplotlib.pyplot as plt
from datetime import datetime

plt.rcParams['figure.figsize'] = (20,15) 
plt.xticks(rotation='vertical', fontsize = 12)
plt.bar(df_tourism.countries, df_tourism.Jan_1978)
plt.savefig('Jan_1978.png',dpi=500)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,15) 
plt.xticks(rotation='vertical', fontsize = 12)
plt.bar(df_tourism.countries, df_tourism.Feb_1978)
plt.savefig('Feb_1978.png',dpi=500)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,15) 
plt.xticks(rotation='vertical', fontsize = 12)
plt.bar(df_tourism.countries, df_tourism.Mar_1978)
plt.savefig('Mar_1978.png',dpi=500)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,15) 
plt.xticks(rotation='vertical', fontsize = 12)
plt.bar(df_tourism.countries, df_tourism.Apr_1978)
plt.savefig('Apr_1978.png',dpi=500)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,15) 
plt.xticks(rotation='vertical', fontsize = 12)
plt.bar(df_tourism.countries, df_tourism.May_1978)
plt.savefig('May_1978.png',dpi=500)
plt.show()

# %%
plt.rcParams['figure.figsize'] = (20,15) 
plt.xticks(rotation='vertical', fontsize = 12)
plt.bar(df_tourism.countries, df_tourism.May_1978)
plt.savefig('May_1978.png',dpi=500)
plt.show()

# %%
dow_dict = {0:'Jan', 1:'Feb', 2:'Mar', 3:'Apr', 4:'May', 5:'Jun', 6:'Jul', 7:'Aug', 8:'Sep', 9:'Oct', 10:'Nov'}
