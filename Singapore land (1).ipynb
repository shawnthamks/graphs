# %%
import pandas as pd

df = pd.read_csv (r"/Users/user/Desktop/total-area-of-state-land-sold-to-private-sector.csv")

print(df)
# Out:
#        month  total_state_land_sold_to_private_sector
# 0    2010-04                                   12.690
# 1    2010-05                                   10.560
# 2    2010-06                                   10.020
# 3    2010-07                                   11.360
# 4    2010-08                                    5.740
# ..       ...                                      ...
# 103  2018-11                                    9.492
# 104  2018-12                                   17.107
# 105  2019-01                                    2.308
# 106  2019-02                                    4.199
# 107  2019-03                                  114.856
#
# [108 rows x 2 columns]

# %%
maxValuesObj = df.max()
 
print('Maximum value in each column : ')
print(maxValuesObj)
# Out:
# Maximum value in each column :
# month                                      2019-03
# total_state_land_sold_to_private_sector     131.24
# dtype: object

# %%
import matplotlib.pyplot as plt
from datetime import datetime

# %%
plt.plot(df.month, df.total_state_land_sold_to_private_sector)
plt.ylabel("Area sold to private sector")
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.title("Total State Land Sold to Private Sector")
plt.text(10, 131.24, "Biggest Area Sold")
plt.style.use('fivethirtyeight')

# %%
import matplotlib.pyplot as plt 
plt.rcParams['figure.figsize'] = (20,15)
